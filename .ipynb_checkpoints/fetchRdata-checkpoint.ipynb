# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:90% !important;}</style>"))

# %%
from rpy2 import robjects
import pandas as pd

# %%
from rpy2.robjects.packages import importr, data

datasets = importr('AppliedPredictiveModeling')
R_data = data(datasets).fetch('segmentationOriginal')['segmentationOriginal']
R_data
# Out:
# <rpy2.robjects.vectors.DataFrame object at 0x7fdaf87cd690> [RTYPES.VECSXP]
# R classes: ('data.frame',)
# [IntSexpVe..., IntSexpVe..., IntSexpVe..., FloatSexp..., ..., FloatSexp..., IntSexpVe..., IntSexpVe..., IntSexpVe...]
#   Cell: <class 'rpy2.robjects.vectors.IntVector'>
#   <rpy2.robjects.vectors.IntVector object at 0x7fdaf87cd730> [RTYPES.INTSXP]
# R classes: ('integer',)
# [207827637, 207932307, 207932463, 207932470, ..., 210952142, 210952338, 210948231, 210948238]
#   Case: <class 'rpy2.robjects.vectors.FactorVector'>
#   <rpy2.robjects.vectors.FactorVector object at 0x7fdaf87cd640> [RTYPES.INTSXP]
# R classes: ('factor',)
# [Test, Train, Train, Train, ..., Test, Test, Test, Train]
#   Class: <class 'rpy2.robjects.vectors.FactorVector'>
#   <rpy2.robjects.vectors.FactorVector object at 0x7fdaf87cd410> [RTYPES.INTSXP]
# R classes: ('factor',)
# [PS, PS, WS, PS, ..., PS, PS, WS, WS]
#   AngleCh1: <class 'rpy2.robjects.vectors.FloatVector'>
#   <rpy2.robjects.vectors.FloatVector object at 0x7fdaf87cd370> [RTYPES.REALSXP]
# R classes: ('numeric',)
# [143.247705, 133.752037, 106.646387, 69.150325, ..., 99.049010, 83.319801, 116.473894, 150.820416]
# ...
#   AreaCh1: <class 'rpy2.robjects.vectors.FloatVector'>
#   <rpy2.robjects.vectors.FloatVector object at 0x7fdaf87cd050> [RTYPES.REALSXP]
# R classes: ('numeric',)
# [10.642974, 32.161261, 21.185525, 13.392830, ..., 24.524072, 9.985410, 22.440286, 21.789495]
#   AreaStatusCh1: <class 'rpy2.robjects.vectors.IntVector'>
#   <rpy2.robjects.vectors.IntVector object at 0x7fdaf87ccfa0> [RTYPES.INTSXP]
# R classes: ('integer',)
# [2, 1, 0, 0, ..., 1, 2, 1, 0]
#   AvgIntenCh1: <class 'rpy2.robjects.vectors.IntVector'>
#   <rpy2.robjects.vectors.IntVector object at 0x7fdaf87ccd70> [RTYPES.INTSXP]
# R classes: ('integer',)
# [42, 215, 371, 487, ..., 313, 291, 100, 71]
#   AvgIntenCh2: <class 'rpy2.robjects.vectors.IntVector'>
#   <rpy2.robjects.vectors.IntVector object at 0x7fdaf87cca50> [RTYPES.INTSXP]
# R classes: ('integer',)
# [14, 347, 252, 295, ..., 88, 402, 448, 480]

# %%
df1 = pd.DataFrame(R_data).T
df1.columns = list(R_data.colnames)

# %%
df1
# Out:
